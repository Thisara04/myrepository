# %%
filePath=r"C:\Users\amtha\myrepository\projectEuler\21-30\MARY,PATRICIA,LINDA,BARBARA,ELIZABE.txt"

# %%
with open(filePath,'r') as file:
    data=file.read().split(",")

# %%
print(dataSet)
# Out:
# []
